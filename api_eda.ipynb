# %%
import pandas as pd

# %% [markdown]
# создадим датасеты под (виды новостей и комании)

# %%
nvidia_controversies = pd.read_csv('nvidia_controversies_2023_2025_oct_drop_duplicates.csv')
nvidia_deals = pd.read_csv('nvidia_deals_2023_2025_oct_drop_duplicates.csv')
nvidia_financial = pd.read_csv('nvidia_financial_2023_2025_oct_drop_duplicates.csv')
nvidia_products = pd.read_csv('nvidia_products_2023jan_2025oct_drop_duplicates.csv')
nvidia_regulatory = pd.read_csv('nvidia_regulatory_2023_2025_oct_drop_duplicates.csv')

# nvidia_competitors = pd.read_csv('')

# %% [markdown]
# Добавим столбец с названием компании и типом новости

# %%
nvidia_controversies['company'] = 'Nvidia'
nvidia_deals['company'] = 'Nvidia'
nvidia_financial['company'] = 'Nvidia'
nvidia_products['company'] = 'Nvidia'
nvidia_regulatory['company'] = 'Nvidia'

# nvidia_competitors['company'] = 'Nvidia'

nvidia_controversies['type'] = 'controversies'
nvidia_deals['type'] = 'deals'
nvidia_financial['type'] = 'financial'
nvidia_products['type'] = 'products'
nvidia_regulatory['type'] = 'regulatory'

# nvidia_competitors['type'] = 'competitors'

# %%
nvidia_controversies
# Out:
#                     date                                              title  \
# 0    2023-01-16 08:00:00  Microsoft, AMD, Nvidia, are all sleeping on Wi...
# 1    2023-02-13 08:00:00  The next NVIDIA GPU shortage might arrive due ...
# 2    2023-05-04 07:00:00  Diagnosing Network Issues Faster with NVIDIA W...
# 3    2023-05-08 07:00:00  Microsoft and AMD are working together to prev...
# 4    2023-05-18 07:00:00  QHack Results Highlight Quantum Computing Appl...
# ..                   ...                                                ...
# 294  2025-10-05 07:00:00  NVIDIA could change cooling solution for Rubin...
# 295  2025-10-10 07:00:00  Department of Commerce issues export licenses ...
# 296  2025-10-10 07:00:00  Singapore company allegedly helped China smugg...
# 297  2025-10-10 07:00:00  Singapore police probe Nvidia customer Megaspe...
# 298  2025-10-18 07:00:00  U.S. Export Ban Wipes Out Nvidia’s China Marke...
#
# ...

# %% [markdown]
# Теперь то же самое по другим компаниям
